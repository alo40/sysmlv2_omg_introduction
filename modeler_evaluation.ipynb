# %% [markdown]
# Import SysMLv2 Model:

# %%
import syside
import os

MAIN_DIR = "/Users/alejandronietocuatenta/Documents/sysmlv2_omg_introduction/"
# MODEL_DIR = "omg_single_example/"
# MODEL_DIR = "omg_introduction/" # mid complexity example
# MODEL_DIR = "omg_simple_vehicle/" # high complexity example
MODEL_DIR = "project_electronics_basics/"

# Construct full directory path
full_dir = os.path.join(MAIN_DIR, MODEL_DIR)

# Find the first file ending with .sysml
for file in os.listdir(full_dir):
    if file.endswith(".sysml"):
        MODEL_FILE_PATH = os.path.join(full_dir, file)
        break  # stop after finding the first .sysml file

(model, diagnostics) = syside.load_model([MODEL_FILE_PATH])

# %% [markdown]
# Evaluate AttributeUsage:

# %%
def safe(expr_func):
    try:
        return expr_func()
    except AttributeError:
        return None

import re
NODE_NAME = r"*"

print("\nPartUsage:") 
for node in model.nodes(syside.PartUsage):
    # if node.name == NODE_NAME:
        print(f"\t{node}")
        # for i, part in enumerate(node.nested_parts.collect()):
        #     print(f"\t\tPart {i} {part}")
        # for i, port in enumerate(node.nested_ports.collect()):
        #     print(f"\t\tPort {i} {port}")
        # for i, attribute in enumerate(node.nested_attributes.collect()):
        #     print(f"\t\tNested attribute {i}")
        #     print(f"\t\t\tname = {attribute.name}")
        #     print(f"\t\t\tvalue = {safe(lambda: attribute.members.collect()[0].value)}")
        # for i, reference in enumerate(node.nested_references.collect()):
        #     print(f"\t\tNested reference {i}")
        #     print(f"\t\t\tname = {reference.name}")
        #     print(f"\t\t\tvalue = {safe(lambda: reference.members.collect()[0].value)}")
        # for i, interface in enumerate(node.nested_interfaces.collect()):
        #     print(f"\t\tInterface {i} {interface}")
        
print("\nPartDefinition:") 
for node in model.nodes(syside.PartDefinition):
    # if node.name == NODE_NAME:
        print(f"\t{node}")
        # for i, part in enumerate(node.nested_parts.collect()):
        #     print(f"\t\tPart {i} {part}")
        # for i, port in enumerate(node.nested_ports.collect()):
        #     print(f"\t\tPort {i} {port}")
        # for i, attribute in enumerate(node.owned_attributes.collect()):
        #     print(f"\t\tAttribute {i}")
        #     print(f"\t\t\tname = {attribute.name}")
        #     print(f"\t\t\tvalue = {safe(lambda: attribute.members.collect()[0].value)}")
        # for i, reference in enumerate(node.owned_references.collect()):
        #     print(f"\t\tReference {i}")
        #     print(f"\t\t\tname = {reference.name}")
        #     print(f"\t\t\tvalue = {safe(lambda: reference.members.collect()[0].value)}")
        # for i, interface in enumerate(node.nested_interfaces.collect()):
        #     print(f"\t\tInterface {i} {interface}")

print("\nAttributeUsage:") 
for node in model.nodes(syside.AttributeUsage):
    # if node.name == NODE_NAME:
        print(f"\t{node}")
       
print("\nReferenceUsage:")
for node in model.nodes(syside.ReferenceUsage):
    # if node.name == NODE_NAME:
        print(f"\t{node}")

# print("\nFeatureValue:")
# for node in model.nodes(syside.FeatureValue):
#     print(f"{node.owned_member_element}")
# Out:
# PartUsage:
# 	Model::Connections::circuit
# 	Model::Connections::b1
# 	Model::Connections::circuit::r1
# 	Model::Connections::circuit::r2
# 	Model::Connections::circuit::l1
# 	Model::Connections::circuit::mcu
#
# PartDefinition:
# 	Model::Definitions::Component
# 	Model::Definitions::Battery
# 	Model::Definitions::Resistor
# 	Model::Definitions::LED
# 	Model::Definitions::Microcontroller
#
# AttributeUsage:
# 	Model::Definitions::Component::voltage
# 	Model::Definitions::Component::current
# 	Model::Definitions::Component::resistance
# 	Model::Definitions::LED::color
# 	Model::Definitions::Microcontroller::memory
# 	Model::Connections::circuit::mcu::pin_no
# 	Model::Connections::circuit::mcu::alu_check
#
# ReferenceUsage:
# 	Model::Definitions::LED::resistance
# 	Model::Connections::circuit::resistance
# 	Model::Connections::circuit::current
# 	Model::Connections::circuit::r1::resistance
# 	Model::Connections::circuit::r2::resistance
# 	Model::Connections::circuit::l1::voltage
# 	Model::Connections::circuit::l1::current
# 	Model::Connections::circuit::l1::color
# 	Model::Connections::circuit::mcu::memory
# 	Model::Connections::b1::voltage

# %% [markdown]
# NOT USED

# %%
  # print(f"\tfeature_value_expression: {safe(lambda: AttributeUsage.feature_value_expression.value)}") # need function "safe" defined above
    # if safe(lambda: AttributeUsage.feature_value_expression.value) != None:
    #     print(f"\tevaluate expression: {syside.Compiler().evaluate(AttributeUsage.feature_value_expression)[0]}")
    # else:
    #     print("\tNo expression found")

# # This one is working! (PartUsage)
        # print(f"\t\treference name = {node.nested_references.collect()[0].name}")
        # print(f"\t\treference value = {node.nested_references.collect()[0].members.collect()[0].value}")
